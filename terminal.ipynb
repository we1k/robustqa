# %%
import os
from google.colab import drive
drive.mount('/content/drive/')

path = '/content/drive/My Drive/robustqa'

os.chdir(path)
os.listdir(path)

# !pip install transformers
# !pip install tensorboardX
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# ...
#      |████████████████████████████████| 3.8 MB 7.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 56.6 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 52.0 MB/s
# ...
#      |████████████████████████████████| 895 kB 48.4 MB/s
# ...
#      |████████████████████████████████| 67 kB 7.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 125 kB 8.7 MB/s
# ...

# %%
# !cp -r ./save/base_adv-03 ../analysis/save

# %%
# %load_ext tensorboard
# %tensorboard --logdir './save'
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 284.

# %%
# !python run.py --do-train  --eval-every 2000 --run-name base_line

# %%
# finetune step
# !python run.py --do-finetune --resume-training  --save-dir save/baseline-02/

# %%
# test evaluation step
# !python run.py --do-eval --resume-training --sub-file val_submission.csv --save-dir save/baseline-02
# Out:
# Some weights of the model checkpoint at ./distilbert-base-uncased were not used when initializing DistilBertForQuestionAnswering: ['vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at ./distilbert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# ...

# %%
# !python train.py --do-train --length-bp-penalty --adv --run-name base_adv
# Out:
# rm: cannot remove './save/base_adv-03': No such file or directory
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForQuestionAnswering: ['vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# baseline 00
# !cp -r ../analysis/save/baseline-00/ ./save
# !python train.py --do-train --resume-training --save-dir ./save/baseline-00 --num-epochs 8

# %%
# !python train.py --do-train --do-finetune --adv --num-epochs 8 --adv-every 5000 --eval-every 2000 --run-name base_adv

# %%
# !python train.py --do-train --length-bp-penalty --adv --num-epoch 8 --adv-every 5000 --eval-every 2000 --run-name base_adv_length
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#  92% 9755/10570 [00:03<00:00, 2778.45it/s]
#  95% 10035/10570 [00:03<00:00, 2675.93it/s]
# 100% 10570/10570 [00:03<00:00, 2717.51it/s]
# [03.09.22 07:52:07] Visualizing in TensorBoard...
# [03.09.22 07:52:07] Eval F1: 76.28, EM: 61.72
# [03.09.22 08:02:50] Evaluating at step 12000...
#  80% 40384/50537 [16:00<03:23, 49.80it/s, Loss=0.744, dis_loss=0.00124, epoch=3]
#   0% 0/10784 [00:00<?, ?it/s]
#   0% 32/10784 [00:00<00:37, 287.22it/s]
#   1% 64/10784 [00:00<00:57, 187.20it/s]
#   1% 96/10784 [00:00<01:03, 167.83it/s]
#   1% 128/10784 [00:00<01:06, 160.68it/s]
#   1% 160/10784 [00:00<01:07, 156.81it/s]
#   2% 192/10784 [00:01<01:08, 154.51it/s]
#   2% 208/10784 [00:01<01:08, 153.55it/s]
#   2% 224/10784 [00:01<01:09, 153.01it/s]
#   2% 240/10784 [00:01<01:09, 152.47it/s]
#   2% 256/10784 [00:01<01:09, 152.03it/s]
#   3% 272/10784 [00:01<01:09, 151.62it/s]
#   3% 288/10784 [00:01<01:09, 151.42it/s]
#   3% 304/10784 [00:01<01:09, 151.26it/s]
# ...
